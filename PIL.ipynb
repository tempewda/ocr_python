# %% [markdown]
# <a href="https://colab.research.google.com/github/ArrowA1/ocr_python/blob/main/PIL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# cloning and uploading files from  github

# %%
# !git clone https://github.com/ArrowA1/ocr_python.git
# Out:
# Cloning into 'ocr_python'...
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 13 (delta 1), reused 7 (delta 0), pack-reused 0
# Unpacking objects: 100% (13/13), done.

# %%
from PIL import Image
im_path = "ocr_python/data/page_01.jpg"
im = Image.open(im_path)

# %%
print(im.format, im.size, im.mode)
# Out:
# JPEG (1200, 1522) RGB

# %% [markdown]
# displaying the image on collab

# %%
from google.colab.patches import cv2_imshow
from skimage import io

image = io.imread(im_path)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x1522 at 0x7FD9469DAD00>
